# %%
from yahoo_fin.stock_info import *
import pandas as pd
from yahoo_fin import options
from yahoo_fin import news

# %%
get_day_losers()
# Out:
#    Symbol                                           Name  Price (Intraday)  \
# 0   SBRCY                             Sberbank of Russia           10.3100
# 1     TPX               Tempur Sealy International, Inc.           30.0600
# 2    VIAC                               Paramount Global           29.5800
# 3   VIACA                               Paramount Global           32.8300
# 4   SHCAY                              Sharp Corporation            2.3401
# ..    ...                                            ...               ...
# 95   MELI                             MercadoLibre, Inc.          883.6300
# 96   CPNG                                  Coupang, Inc.           21.6700
# 97   CORZ                          Core Scientific, Inc.            7.7800
# 98  RLLCF                       Rolls-Royce Holdings plc            0.0130
# 99    MBT  Mobile TeleSystems Public Joint Stock Company            6.7600
#
# ...

# %%
df_aapl = get_cash_flow("aapl")

# %%
get_quote_data("cvx")
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'currency': 'USD',
#  'exchange': 'NYQ',
#  'shortName': 'Chevron Corporation',
#  'longName': 'Chevron Corporation',
#  'marketState': 'REGULAR',
#  'messageBoardId': 'finmb_98506',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'firstTradeDateMilliseconds': -252322200000,
#  'priceHint': 2,
#  'regularMarketChange': -2.300003,
#  'regularMarketChangePercent': -1.7238818,
#  'regularMarketTime': 1645556699,
#  'regularMarketPrice': 131.12,
#  'regularMarketDayHigh': 137.04,
#  'regularMarketDayRange': '130.52 - 137.04',
#  'regularMarketDayLow': 130.52,
#  'regularMarketVolume': 10849849,
#  'regularMarketPreviousClose': 133.42,
#  'bid': 130.81,
#  'ask': 130.84,
#  'bidSize': 8,
#  'askSize': 8,
# ...
